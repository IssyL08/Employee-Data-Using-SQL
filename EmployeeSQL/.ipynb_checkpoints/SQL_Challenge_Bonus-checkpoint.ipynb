# %% [markdown]
# # Bonus (Optional)
#
# As you examine the data, you are overcome with a creeping suspicion that the dataset is fake. You surmise that your boss handed you spurious data in order to test the data engineering skills of a new employee. To confirm your hunch, you decide to take the following steps to generate a visualization of the data, with which you will confront your boss:
#
# 1. Import the SQL database into Pandas. (Yes, you could read the CSVs directly in Pandas, but you are, after all, trying to prove your technical mettle.) This step may require some research. Feel free to use the code below to get started. Be sure to make any necessary modifications for your username, password, host, port, and database name:
#
#    ```sql
#    from sqlalchemy import create_engine
#    engine = create_engine('postgresql://localhost:5432/<your_db_name>')
#    connection = engine.connect()
#    ```
#
# * Consult [SQLAlchemy documentation](https://docs.sqlalchemy.org/en/latest/core/engines.html#postgresql) for more information.
#
# * If using a password, do not upload your password to your GitHub repository. See [https://www.youtube.com/watch?v=2uaTPmNvH0I](https://www.youtube.com/watch?v=2uaTPmNvH0I) and [https://help.github.com/en/github/using-git/ignoring-files](https://help.github.com/en/github/using-git/ignoring-files) for more information.
#
# 2. Create a histogram to visualize the most common salary ranges for employees.
#
# 3. Create a bar chart of average salary by title.
#
# See below for importing of the sql file into Pandas and processing the data here within the pandas data file

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import urllib.parse
import psycopg2
import pandas.io.sql as psql
from sqlalchemy import create_engine

# %%
# Connection parameters, yours will be different
param_dic = {
    "host"      : "localhost",
    "database"  : "SQL_CHallenge",
    "user"      : "postgres",
    "password"  : "Tic@tac56"
}

def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

# %%
def postgresql_to_dataframe(conn, select_query, column_names):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df
    print(df)

# %%
conn = connect(param_dic)
column_names = ["emp_no", "salary"]

# Execute the "SELECT *" query
salaries_df = postgresql_to_dataframe(conn, "SELECT * FROM salaries", column_names)
salaries_df.head()
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
#Salaries Dataframe

salaries = pd.read_sql("SELECT * FROM salaries", conn)
salaries.head(10)
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228
# 5   10006   40000
# 6   10007   56724
# 7   10008   46671
# 8   10009   60929
# 9   10010   72488

# %%
# Renaming Columns for a cleaner look
salaries_clean = salaries.rename(columns={"emp_no": "Employee Number", "salary": "Salary",})
salaries_clean.head(10)
# Out:
#    Employee Number  Salary
# 0            10001   60117
# 1            10002   65828
# 2            10003   40006
# 3            10004   40054
# 4            10005   78228
# 5            10006   40000
# 6            10007   56724
# 7            10008   46671
# 8            10009   60929
# 9            10010   72488

# %%
# Employees Dataframe

employees = pd.read_sql("SELECT * FROM employees", conn)
# employees.head(10)

# Renaming Columns for a cleaner look
employees_clean = employees.rename(columns={"emp_no": "Employee Number","emp_title_id":"Employee Title ID","birth_date": "Birth Date", "first_name" : "First Name", "last_name" : "Last Name", "sex" : "Gender", "hire_date" : "Hire Date"})
employees_clean.head(10)
# Out:
#    Employee Number Employee Title ID  Birth Date  First Name  Last Name  \
# 0           473302             s0001  1953-07-25    Hideyuki   Zallocco
# 1           475053             e0002  1954-11-18       Byong  Delgrande
# 2            57444             e0002  1958-01-30       Berry       Babb
# 3           421786             s0001  1957-09-28       Xiong   Verhoeff
# 4           282238             e0003  1952-10-28  Abdelkader    Baumann
# 5           263976             e0003  1959-10-30        Eran   Cusworth
# 6           273487             s0001  1957-04-14   Christoph    Parfitt
# 7           461591             s0002  1964-11-17      Xudong   Samarati
# 8           477657             e0002  1962-12-18      Lihong  Magliocco
# 9           219881             s0002  1956-04-24   Kwangyoen      Speek
#
#   Gender   Hire Date
# 0      M  1990-04-28
# 1      F  1991-09-07
# 2      F  1992-03-21
# 3      M  1987-11-26
# 4      F  1991-01-18
# 5      M  1986-11-14
# 6      M  1991-06-28
# 7      M  1985-11-13
# 8      M  1993-10-23
# 9      F  1993-02-14

# %%
# Department Employee Dataframe

dept_employee = pd.read_sql("SELECT * FROM dept_employee", conn)
dept_employee.head(10)

dept_employee_clean = dept_employee.rename(columns={"emp_no": "Employee Number", "dept_no": "Department Number", })
dept_employee_clean.head(10)
# Out:
#    Employee Number Department Number
# 0            10001              d005
# 1            10002              d007
# 2            10003              d004
# 3            10004              d004
# 4            10005              d003
# 5            10006              d005
# 6            10007              d008
# 7            10008              d005
# 8            10009              d006
# 9            10010              d004

# %%
# Departments Dataframe

departments = pd.read_sql("SELECT * FROM departments", conn)
departments.head(10)

departments_clean = departments.rename(columns={"dept_name": "Department Name", "dept_no": "Department Number"})
departments_clean.head(10)
# Out:
#   Department Number     Department Name
# 0              d001           Marketing
# 1              d002             Finance
# 2              d003     Human Resources
# 3              d004          Production
# 4              d005         Development
# 5              d006  Quality Management
# 6              d007               Sales
# 7              d008            Research
# 8              d009    Customer Service

# %%
#departments_clean.to_csv('Outputs/salaries_clean.csv', index=False)

# %%
# Titles Dataframe

titles = pd.read_sql("SELECT * FROM titles", conn)
# titles.head(10)

titles_clean = titles.rename(columns={"title_id":"Employee Title ID", "title": "Title", })
titles_clean.head(10)
# Out:
#   Employee Title ID               Title
# 0             s0001               Staff
# 1             s0002        Senior Staff
# 2             e0001  Assistant Engineer
# 3             e0002            Engineer
# 4             e0003     Senior Engineer
# 5             e0004    Technique Leader
# 6             m0001             Manager

# %%
# Merge DF -- Employees and Salaries

employees_salaries = pd.merge(employees_clean, salaries_clean, on="Employee Number", how="inner")
employees_salaries.head(10)
# Out:
#    Employee Number Employee Title ID  Birth Date  First Name  Last Name  \
# 0           473302             s0001  1953-07-25    Hideyuki   Zallocco
# 1           475053             e0002  1954-11-18       Byong  Delgrande
# 2            57444             e0002  1958-01-30       Berry       Babb
# 3           421786             s0001  1957-09-28       Xiong   Verhoeff
# 4           282238             e0003  1952-10-28  Abdelkader    Baumann
# 5           263976             e0003  1959-10-30        Eran   Cusworth
# 6           273487             s0001  1957-04-14   Christoph    Parfitt
# 7           461591             s0002  1964-11-17      Xudong   Samarati
# 8           477657             e0002  1962-12-18      Lihong  Magliocco
# 9           219881             s0002  1956-04-24   Kwangyoen      Speek
#
#   Gender   Hire Date  Salary
# 0      M  1990-04-28   40000
# 1      F  1991-09-07   53422
# 2      F  1992-03-21   48973
# 3      M  1987-11-26   40000
# 4      F  1991-01-18   40000
# 5      M  1986-11-14   40000
# 6      M  1991-06-28   56087
# 7      M  1985-11-13   40000
# 8      M  1993-10-23   54816
# 9      F  1993-02-14   40000

# %%
# Merge DF -- on Employee Number, common -- Salaries and Titles 

salaries_titles = pd.merge(employees_salaries, titles_clean, on="Employee Title ID", how="inner" )

salaries_titles.head(10)
# Out:
#    Employee Number Employee Title ID  Birth Date  First Name   Last Name  \
# 0           473302             s0001  1953-07-25    Hideyuki    Zallocco
# 1           421786             s0001  1957-09-28       Xiong    Verhoeff
# 2           273487             s0001  1957-04-14   Christoph     Parfitt
# 3           246449             s0001  1958-03-23       Subbu  Bultermann
# 4            48085             s0001  1964-01-19  Venkatesan        Gilg
# 5           476443             s0001  1952-08-27        Ziya      Asmuth
# 6           424270             s0001  1963-01-15      Kellyn   Yoshizawa
# 7           427958             s0001  1957-05-03    Feixiong      Poujol
# 8           280408             s0001  1964-09-19     Elliott        Perl
# 9           229010             s0001  1961-11-12        Mark    Cappelli
#
#   Gender   Hire Date  Salary  Title
# 0      M  1990-04-28   40000  Staff
# 1      M  1987-11-26   40000  Staff
# 2      M  1991-06-28   56087  Staff
# 3      F  1988-03-25   87084  Staff
# 4      M  1993-06-28   63016  Staff
# 5      M  1995-08-24   63371  Staff
# 6      F  1995-05-08   60678  Staff
# 7      F  1985-05-11   63377  Staff
# 8      M  1987-10-29   75963  Staff
# 9      M  1990-05-07   40000  Staff

# %%
salaries_titles_grouped_df = salaries_titles.groupby("Title").mean()
salaries_titles_grouped_df
# Out:
#                     Employee Number        Salary
# Title
# Assistant Engineer    252992.595373  48564.434447
# Engineer              253654.345919  48535.336511
# Manager               110780.833333  51531.041667
# Senior Engineer       253038.749885  48506.799871
# Senior Staff          254481.798969  58550.172704
# Staff                 253408.503604  58465.382850
# Technique Leader      251811.432730  48582.896092

# %%
# Dropping the Employee Number as it's no longer needed, makes it easier to visualize the plots

title_salary_df = salaries_titles_grouped_df.drop(columns = "Employee Number")
title_salary_df = title_salary_df.reset_index()
title_salary_df
# Out:
#                 Title        Salary
# 0  Assistant Engineer  48564.434447
# 1            Engineer  48535.336511
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.799871
# 4        Senior Staff  58550.172704
# 5               Staff  58465.382850
# 6    Technique Leader  48582.896092

# %%
# Salary by Employees

salaries_employees = pd.merge(salaries_clean, employees_clean, on="Employee Number", how="inner")
salaries_employees.head(10)
# Out:
#    Employee Number  Salary Employee Title ID  Birth Date First Name  \
# 0            10001   60117             e0003  1953-09-02     Georgi
# 1            10002   65828             s0001  1964-06-02    Bezalel
# 2            10003   40006             e0003  1959-12-03      Parto
# 3            10004   40054             e0003  1954-05-01  Chirstian
# 4            10005   78228             s0001  1955-01-21    Kyoichi
# 5            10006   40000             e0003  1953-04-20     Anneke
# 6            10007   56724             s0001  1957-05-23    Tzvetan
# 7            10008   46671             e0001  1958-02-19     Saniya
# 8            10009   60929             e0003  1952-04-19     Sumant
# 9            10010   72488             e0002  1963-06-01  Duangkaew
#
#    Last Name Gender   Hire Date
# 0    Facello      M  1986-06-26
# 1     Simmel      F  1985-11-21
# 2    Bamford      M  1986-08-28
# 3    Koblick      M  1986-12-01
# 4   Maliniak      M  1989-09-12
# 5    Preusig      F  1989-06-02
# 6  Zielinski      F  1989-02-10
# 7   Kalloufi      M  1994-09-15
# 8       Peac      F  1985-02-18
# 9   Piveteau      F  1989-08-24

# %%
# Merge Departments and Department Employee

dept_dept_emp = pd.merge(departments_clean, dept_employee_clean, on="Department Number", how="inner")
dept_dept_emp.head(10)
# Out:
#   Department Number Department Name  Employee Number
# 0              d001       Marketing            10017
# 1              d001       Marketing            10055
# 2              d001       Marketing            10058
# 3              d001       Marketing            10108
# 4              d001       Marketing            10140
# 5              d001       Marketing            10175
# 6              d001       Marketing            10208
# 7              d001       Marketing            10228
# 8              d001       Marketing            10239
# 9              d001       Marketing            10259

# %%
# Merge salaries_department to dept_dept_emp

second_merge_on_emp_no = pd.merge(employees_salaries, dept_dept_emp, on="Employee Number", how="inner")
second_merge_on_emp_no.head(10)
# Out:
#    Employee Number Employee Title ID  Birth Date  First Name  Last Name  \
# 0           473302             s0001  1953-07-25    Hideyuki   Zallocco
# 1           475053             e0002  1954-11-18       Byong  Delgrande
# 2            57444             e0002  1958-01-30       Berry       Babb
# 3           421786             s0001  1957-09-28       Xiong   Verhoeff
# 4           282238             e0003  1952-10-28  Abdelkader    Baumann
# 5           263976             e0003  1959-10-30        Eran   Cusworth
# 6           273487             s0001  1957-04-14   Christoph    Parfitt
# 7           461591             s0002  1964-11-17      Xudong   Samarati
# 8           477657             e0002  1962-12-18      Lihong  Magliocco
# 9           219881             s0002  1956-04-24   Kwangyoen      Speek
#
#   Gender   Hire Date  Salary Department Number     Department Name
# 0      M  1990-04-28   40000              d002             Finance
# 1      F  1991-09-07   53422              d004          Production
# 2      F  1992-03-21   48973              d004          Production
# 3      M  1987-11-26   40000              d003     Human Resources
# 4      F  1991-01-18   40000              d006  Quality Management
# 5      M  1986-11-14   40000              d006  Quality Management
# 6      M  1991-06-28   56087              d003     Human Resources
# 7      M  1985-11-13   40000              d002             Finance
# 8      M  1993-10-23   54816              d006  Quality Management
# 9      F  1993-02-14   40000              d009    Customer Service

# %%
# Merge salaries_department to dept_dept_emp

second_merge_on_emp_no = pd.merge(salaries_employees, dept_dept_emp, on="Employee Number", how="inner")
second_merge_on_emp_no.head(10)
# Out:
#    Employee Number  Salary Employee Title ID  Birth Date First Name  \
# 0            10001   60117             e0003  1953-09-02     Georgi
# 1            10002   65828             s0001  1964-06-02    Bezalel
# 2            10003   40006             e0003  1959-12-03      Parto
# 3            10004   40054             e0003  1954-05-01  Chirstian
# 4            10005   78228             s0001  1955-01-21    Kyoichi
# 5            10006   40000             e0003  1953-04-20     Anneke
# 6            10007   56724             s0001  1957-05-23    Tzvetan
# 7            10008   46671             e0001  1958-02-19     Saniya
# 8            10009   60929             e0003  1952-04-19     Sumant
# 9            10010   72488             e0002  1963-06-01  Duangkaew
#
#    Last Name Gender   Hire Date Department Number     Department Name
# 0    Facello      M  1986-06-26              d005         Development
# 1     Simmel      F  1985-11-21              d007               Sales
# 2    Bamford      M  1986-08-28              d004          Production
# 3    Koblick      M  1986-12-01              d004          Production
# 4   Maliniak      M  1989-09-12              d003     Human Resources
# 5    Preusig      F  1989-06-02              d005         Development
# 6  Zielinski      F  1989-02-10              d008            Research
# 7   Kalloufi      M  1994-09-15              d005         Development
# 8       Peac      F  1985-02-18              d006  Quality Management
# 9   Piveteau      F  1989-08-24              d004          Production

# %%
second_merge_on_emp_no.columns
# Out:
# Index(['Employee Number', 'Salary', 'Employee Title ID', 'Birth Date',
#        'First Name', 'Last Name', 'Gender', 'Hire Date', 'Department Number',
#        'Department Name'],
#       dtype='object')

# %%
# Drop and Clean

clean_second_merge = second_merge_on_emp_no.drop(columns = ["Department Number", "Hire Date", "Birth Date"])
clean_second_merge.head()
# Out:
#    Employee Number  Salary Employee Title ID First Name Last Name Gender  \
# 0            10001   60117             e0003     Georgi   Facello      M
# 1            10002   65828             s0001    Bezalel    Simmel      F
# 2            10003   40006             e0003      Parto   Bamford      M
# 3            10004   40054             e0003  Chirstian   Koblick      M
# 4            10005   78228             s0001    Kyoichi  Maliniak      M
#
#    Department Name
# 0      Development
# 1            Sales
# 2       Production
# 3       Production
# 4  Human Resources

# %%
# Plotting Salary by Department

plt.hist(clean_second_merge["Salary"], color='blue', alpha=1);

plt.xlabel("\nSALARY RANGE ($)", weight="bold");
plt.ylabel("NUMBER OF EMPLOYEES\n", weight="bold");
plt.title("SALARY RANGE PER EMPLOYEES\n", weight="bold", size=15)

plt.grid()
plt.tight_layout()

plt.savefig("Outputs/Hist_By_Dept_Salaries_Range.png")

# %%
# Salary by Title 

plt.hist(salaries_titles["Salary"], color='purple', alpha=1);

plt.xlabel("\nSALARY RANGE ($)", weight="bold");
plt.ylabel("NUMBER OF EMPLOYEES\n", weight="bold");
plt.title("SALARY RANGE PER EMPLOYEES\n", weight="bold", size=15)

plt.grid()
plt.tight_layout()

plt.savefig("Outputs/Hist_Employee_Salary_Range.png")

# %%
# Create a bar chart of average salary by title.

x_axis = title_salary_df["Title"]
y_axis = title_salary_df["Salary"]

plt.bar(x_axis, y_axis, color='lightblue', alpha=1)

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, x_axis, rotation=90);

plt.xlabel("\nTITLE", weight="bold")
plt.ylabel("AVERAGE SALARY\n", weight="bold")
plt.title("AVERAGE SALARY BY TITLE\n", weight="bold", size=15)

plt.grid()
plt.tight_layout()

plt.savefig("Outputs/Bar_Avg_Salary_By_Title.png")

# %%
#printing cleaned tables to csv
salaries_clean.to_csv('Outputs/salaries_clean.csv', index=False)
employees_clean.to_csv('Outputs/employees_clean.csv', index=False)
dept_employee_clean.to_csv('Outputs/dept_employee_clean.csv', index=False)
departments_clean.to_csv('Outputs/departments_clean.csv', index=False)
